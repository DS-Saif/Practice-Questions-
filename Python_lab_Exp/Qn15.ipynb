# %% [markdown]
# # AIM: To copy content from one file to another.

# %%
with open(r"C:\Users\Asus\database\marksheet.csv", "r") as f1:
    data = f1.read()

with open("b.txt", "w") as f2:
    f2.write(data)
