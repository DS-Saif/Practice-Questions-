# %% [markdown]
# # AIM: To sort employees based on salary.

# %%
emp={"Suman":50000,"Aman":40000,"Neha":60000}
sorted_emp=sorted(emp.items(),key=lambda x:x[1])
print(sorted_emp)
# Out:
# [('Aman', 40000), ('Suman', 50000), ('Neha', 60000)]
