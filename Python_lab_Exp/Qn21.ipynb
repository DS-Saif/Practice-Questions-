# %% [markdown]
# # AIM: To display all installed Python packages.

# %%
# AIM: To display all installed Python packages.

import pkg_resources

for p in pkg_resources.working_set:
    print(p.project_name)
# Out:
# MarkupSafe
# anyio
# argon2-cffi
# argon2-cffi-bindings
# asttokens
# async-lru
# attrs
# babel
# beautifulsoup4
# bleach
# bottleneck
# brotlicffi
# certifi
# cffi
# charset-normalizer
# click
# colorama
# comm
# contourpy
# cycler
# debugpy
# decorator
# defusedxml
# exceptiongroup
# executing
# fastjsonschema
# fonttools
# h11
# html5lib
# httpcore
# httpx
# idna
# ipykernel
# ipython
# jedi
# jinja2
# joblib
# json5
# jsonschema
# jsonschema-specifications
# jupyter-client
# jupyter-core
# jupyter-events
# jupyter-lsp
# jupyter-server
# jupyter-server-terminals
# jupyterlab
# jupyterlab-pygments
# jupyterlab-server
# kiwisolver
# matplotlib
# matplotlib-inline
# mistune
# mkl-fft
# mkl-random
# mkl-service
# nbclient
# nbconvert
# nbformat
# nest-asyncio
# nltk
# notebook-shim
# numexpr
# numpy
# overrides
# packaging
# pandas
# pandocfilters
# parso
# pillow
# pip
# platformdirs
# prometheus-client
# prompt-toolkit
# psutil
# pure-eval
# pycparser
# pygments
# pyparsing
# pyqt6
# ...
