# %% [markdown]
# # Install Python and Verify Installation

# %% [markdown]
#  To install Python interpreter.
#  To configure development environment.
# COMMAND:
# python --version
# OUTPUT:
# Displays installed Python version (e.g., Python 3.11.2)
# RESULT:
# Python installed and verified successfully.
